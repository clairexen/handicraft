# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import multiphaseavg

np.random.seed(42)

with open("testbench.dat", "w") as f:
    plt.figure(figsize=(15,5))
    multiphaseavg.testbench(1024, plt, f)
